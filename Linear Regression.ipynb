# %%
import pandas
from pandas import DataFrame
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

# %%
data = pandas.read_csv('cost_revenue_clean.csv')

# %%
data.describe()
# Out:
#        production_budget_usd  worldwide_gross_usd
# count           5.034000e+03         5.034000e+03
# mean            3.290784e+07         9.515685e+07
# std             4.112589e+07         1.726012e+08
# min             1.100000e+03         2.600000e+01
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296202e+07
# 75%             4.200000e+07         1.034471e+08
# max             4.250000e+08         2.783919e+09

# %%
3.29e7
# Out:
# 32900000.0

# %%
x = DataFrame(data, columns = ['production_budget_usd'])
y = DataFrame(data, columns = ['worldwide_gross_usd'])

# %%
plt.figure(figsize = (10, 6))
plt.scatter(x, y, alpha=0.3 )
plt.title('Film Cost vs Global Revenue')
plt.xlabel('Production Budget $')
plt.ylabel('Woldwide Gross $')
plt.ylim(0, 3000000000)
plt.xlim(0, 450000000)
plt.show()

# %%
regr = LinearRegression()
regr.fit(x, y)
# Out:
# LinearRegression()

# %% [markdown]
# Slope Coefficient

# %%
regr.coef_ # theta_1
# Out:
# array([[3.11150918]])

# %%
# Intercept
regr.intercept_
# Out:
# array([-7236192.72913988])

# %%
type(regr.intercept_)
# Out:
# numpy.ndarray

# %%
regr.intercept_[0]
# Out:
# -7236192.729139879

# %%
plt.figure(figsize = (10, 6))
plt.scatter(x, y, alpha=0.3 )
plt.plot(x, regr.predict(x), color='red', linewidth=4)

plt.title('Film Cost vs Global Revenue')
plt.xlabel('Production Budget $')
plt.ylabel('Woldwide Gross $')
plt.ylim(0, 3000000000)
plt.xlim(0, 450000000)
plt.show()

# %%
regr.score(x,y)
# Out:
# 0.5496485356985729

# %%
import life as life

# %%
type(life)
# Out:
# module

# %%
life.theAnswer
# Out:
# 42

# %%
import math

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
print(math.e)
# Out:
# 2.718281828459045

# %%
from life import theAnswer

# %%
myFavoriteNumber = theAnswer

# %%
print(myFavoriteNumber)
# Out:
# 42

# %%
theAnswer = theAnswer + 1
print(theAnswer)
# Out:
# 43

# %%
# The from keyword copies out a value from the module and makes it accessable to you as a variable but the value inside of the module has not been changed

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
def get_milk():
    print('Open door')
    print('Walk to the store')
    print('Buy milk on the ground floor')
    print('return with milk galore')

# %%
get_milk()
# Out:
# Open door
# Walk to the store
# Buy milk on the ground floor
# return with milk galore

# %%
import pandas as pd
data = pd.read_csv('lsd_math_score_data.csv')

# %%
print(data)
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score
# 0                      5     1.17                78.93
# 1                     15     2.97                58.20
# 2                     30     3.26                67.47
# 3                     60     4.69                37.47
# 4                    120     5.83                45.65
# 5                    240     6.00                32.92
# 6                    480     6.41                29.97

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
onlyMathScores = data['Avg_Math_Test_Score']
print(onlyMathScores)
# Out:
# 0    78.93
# 1    58.20
# 2    67.47
# 3    37.47
# 4    45.65
# 5    32.92
# 6    29.97
# Name: Avg_Math_Test_Score, dtype: float64

# %%
data['Test_Subject'] = 'Jenifer Lopez'

# %%
print(data)
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score   Test_Subject
# 0                      5     1.17                78.93  Jenifer Lopez
# 1                     15     2.97                58.20  Jenifer Lopez
# 2                     30     3.26                67.47  Jenifer Lopez
# 3                     60     4.69                37.47  Jenifer Lopez
# 4                    120     5.83                45.65  Jenifer Lopez
# 5                    240     6.00                32.92  Jenifer Lopez
# 6                    480     6.41                29.97  Jenifer Lopez

# %%
data['High_Score'] = 100
print(data)
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score   Test_Subject  \
# 0                      5     1.17                78.93  Jenifer Lopez
# 1                     15     2.97                58.20  Jenifer Lopez
# 2                     30     3.26                67.47  Jenifer Lopez
# 3                     60     4.69                37.47  Jenifer Lopez
# 4                    120     5.83                45.65  Jenifer Lopez
# 5                    240     6.00                32.92  Jenifer Lopez
# 6                    480     6.41                29.97  Jenifer Lopez
#
#    High_Score
# 0         100
# 1         100
# 2         100
# 3         100
# 4         100
# 5         100
# 6         100

# %%
data['High_Score'] = data['High_Score'] + data['Avg_Math_Test_Score']
print(data)
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score   Test_Subject  \
# 0                      5     1.17                78.93  Jenifer Lopez
# 1                     15     2.97                58.20  Jenifer Lopez
# 2                     30     3.26                67.47  Jenifer Lopez
# 3                     60     4.69                37.47  Jenifer Lopez
# 4                    120     5.83                45.65  Jenifer Lopez
# 5                    240     6.00                32.92  Jenifer Lopez
# 6                    480     6.41                29.97  Jenifer Lopez
#
#    High_Score
# 0      178.93
# 1      158.20
# 2      167.47
# 3      137.47
# 4      145.65
# 5      132.92
# 6      129.97

# %%
data['High_Score'] = data['High_Score'] ** 2
print(data)
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score   Test_Subject  \
# 0                      5     1.17                78.93  Jenifer Lopez
# 1                     15     2.97                58.20  Jenifer Lopez
# 2                     30     3.26                67.47  Jenifer Lopez
# 3                     60     4.69                37.47  Jenifer Lopez
# 4                    120     5.83                45.65  Jenifer Lopez
# 5                    240     6.00                32.92  Jenifer Lopez
# 6                    480     6.41                29.97  Jenifer Lopez
#
#    High_Score
# 0  32015.9449
# 1  25027.2400
# 2  28046.2009
# 3  18898.0009
# 4  21213.9225
# 5  17667.7264
# 6  16892.2009

# %%
type(onlyMathScores)
# Out:
# pandas.core.series.Series

# %%
#Challenge: Create a list called columnList. Put 'LSD_ppm' and "AVg_Math_Test_score' inside.
# columnList= ['LSD_ppm', 'Avg_Math_Test_Score']
cleanData = data[['LSD_ppm', 'Avg_Math_Test_Score']]
print(cleanData)
# Out:
#    LSD_ppm  Avg_Math_Test_Score
# 0     1.17                78.93
# 1     2.97                58.20
# 2     3.26                67.47
# 3     4.69                37.47
# 4     5.83                45.65
# 5     6.00                32.92
# 6     6.41                29.97

# %%
type(cleanData)
# Out:
# pandas.core.frame.DataFrame

# %%
# When we pass in a string then we get a series but when we provide a list we get out a data 
# frame. A string would only be one pair of brackets.
y = data[['Avg_Math_Test_Score']]
type(y)
# Out:
# pandas.core.frame.DataFrame

# %%
# Challenge: Create a variable called X
# Set X equa to the values of LSD_ppm
# Make sure X us a dataframe
# 2) print the value of x
#  30 show the type of X

# %%
X = data[['LSD_ppm']]
print(X)
type(X)
# Out:
#    LSD_ppm
# 0     1.17
# 1     2.97
# 2     3.26
# 3     4.69
# 4     5.83
# 5     6.00
# 6     6.41
# pandas.core.frame.DataFrame

# %%
del data['Test_Subject']
print(data)
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score  High_Score
# 0                      5     1.17                78.93  32015.9449
# 1                     15     2.97                58.20  25027.2400
# 2                     30     3.26                67.47  28046.2009
# 3                     60     4.69                37.47  18898.0009
# 4                    120     5.83                45.65  21213.9225
# 5                    240     6.00                32.92  17667.7264
# 6                    480     6.41                29.97  16892.2009

# %%
def times(a,b):
    return  a * b

# %%
test = times(3.14, 5.09)
print(test)
# Out:
# 15.9826

# %%
life.quote_marvin()
# Out:
# Ive calculated your chance of survival, but I don't think you'll like it

# %%
print(life.square_root(4))
# Out:
# 2.0

# %%
data
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score  High_Score
# 0                      5     1.17                78.93  32015.9449
# 1                     15     2.97                58.20  25027.2400
# 2                     30     3.26                67.47  28046.2009
# 3                     60     4.69                37.47  18898.0009
# 4                    120     5.83                45.65  21213.9225
# 5                    240     6.00                32.92  17667.7264
# 6                    480     6.41                29.97  16892.2009

# %%
time = data[['Time_Delay_in_Minutes']]
LSD = data[['LSD_ppm']]
score = data[['Avg_Math_Test_Score']]

# %%
# %matplotlib inline

plt.title('Tissue concentration of LSD over time',fontsize=17)
plt.xlabel('Time in Minutes', fontsize=14)
plt.ylabel('Tissue LSD ppm', fontsize=14) 
plt.text(x=0, y=-0.5, s='Wagner et al. (1968)', fontsize=12)
plt.yticks(fontsize=10)
plt.ylim(1,7)
plt.xlim(0,500)

plt.style.use('classic')

plt.plot(time,LSD, color= '#e74c3c', linewidth=3)
plt.show()

# %%
regr = LinearRegression()
regr.fit(LSD, score)
print('Theta1 : ', regr.coef_[0][0])
print('Intercept: ', regr.intercept_[0])
print('R-square: ', regr.score(LSD, score))
predicted_score = regr.predict(LSD)
# Out:
# Theta1 :  -9.009466415296783
# Intercept:  89.12387376799306
# R-square:  0.8778349707775888

# %% [raw]
# %matplotlib inline
#
# plt.scatter(LSD, score, color='blue', s=100, alpha=0.7)
# plt.style.use('fivethirtyeight')
# plt.title('Arithmetic vs LSD-25', fontsize=17)
# plt.xlabel('Tissue LSD ppm', fontsize=14)
# plt.ylabel('Performance Score', fontsize=14)
# plt.ylim(25,85)
# plt.xlim(1, 6.6)
#
#
# plt.show()

# %%
plt.scatter(LSD, score, color='blue', s=100, alpha=0.7)
plt.style.use('fivethirtyeight')
plt.title('Arithmetic vs LSD-25', fontsize=17)
plt.xlabel('Tissue LSD ppm', fontsize=14)
plt.ylabel('Performance Score', fontsize=14)
plt.ylim(25,85)
plt.xlim(1, 6.6)


plt.show()
